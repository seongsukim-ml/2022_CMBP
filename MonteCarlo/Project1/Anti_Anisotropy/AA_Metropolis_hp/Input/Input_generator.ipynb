# %%
## Code 1: runnable code automation

runnablefile   = "AA_Metropolis_correlation_Jackknife_short.out"
inputpath      = "./Input"
folder_prefix  = "1018"
iterate        = 1   ## The number of data index data1 to data 1+iter
idx            = 100   ## Folder num ex 1018_idx
filenum        = 1   ## The number of start idx of file
datanum        = 8   ## The number of start idx of data
option         = 'cor'  ## folder name option ex 1018_Sus0 (bbin, Sus, cor)
total_iterate  = 2

for j in range(total_iterate):
    for i in range(iterate):
        if filenum != 1:
            print(("./{} {}/{}_"+option+"{}/data{}.txt {};").format(runnablefile,inputpath,folder_prefix,idx,i+datanum,filenum),end=" ")
        else:
            print(("./{} {}/{}_"+option+"{}/data{}.txt;").format(runnablefile,inputpath,folder_prefix,idx,i+datanum),end=" ")
# Out:
# ./AA_Metropolis_correlation_Jackknife_short.out ./Input/1018_cor100/data8.txt; ./AA_Metropolis_correlation_Jackknife_short.out ./Input/1018_cor100/data8.txt;

# %%
from genericpath import exists
import os

def input_data_generator(save_path, folder_name, lattice, equil, mcs, Tsrt, Tfin, alpha,
                        kBin = 21, kB = 0, kJx = 1, kJy = -1, isTinf = 0, Random = 0):
    path_f = save_path + '/' + folder_name
    if not os.path.exists(path_f):
        os.mkdir(path_f)
    for i, Lsize in enumerate(lattice):
        file_name = "data" + str(i+1) + ".txt"
        file = open(path_f + "/" + file_name, "w")
        file.write("kXy             = {}\n".format(Lsize))
        file.write("kLy             = {}\n".format(Lsize))
        file.write("\n")
        file.write("kBin            = {}\n".format(kBin))
        file.write("\n")
        file.write("kB              = {}\n".format(kB))
        file.write("kJx             = {}\n".format(kJx))
        file.write("kJy             = {}\n".format(kJy))
        file.write("alpha           = {}\n".format(alpha))
        file.write("\n")
        file.write("Tsrt            = {}\n".format(Tsrt))
        file.write("Tfin            = {}\n".format(Tfin))
        file.write("\n")
        file.write("isTinf          = {}\n".format(isTinf))
        file.write("Random          = {}\n".format(Random))
        file.write("\n")
        file.write("equil_time_base = {}\n".format(equil[Lsize]))
        file.write("mcs             = {}\n".format(mcs[Lsize]))
        file.close()

# %%
## Code 2: Input configuration file generator

path    = "./"
# lattice = [16,32,48,64,80]
lattice = [6,8,12,24,32,48,64,80]

# alpha2   = [0.5,0.75,1.25,1.75,2.25,2.75,3.25,3.75,4]
alpha2   = [100]

equil_dict = {
    6 :500000,
    8 :500000,
    12:500000,
    16:500000,
    24:500000,
    32:500000,
    48:500000,
    64:500000,
    80:5000000,
    128:5000000
    }

mcs_dict   = {
    6 :20000000,
    8 :20000000,
    12:20000000,
    16:20000000,
    24:20000000,
    32:20000000,
    48:20000000,
    64:20000000,
    80:20000000,
    128:20000000
    }

alpha_crit_range_dict_ideal = {
                    "a=0.5"  :[1.34,1.38],
                    "a=0.75" :[1.50,1.54],
                    # "a=1"    :[1.61,1.65], #checked
                    "a=1"    :[1.625,1.635], #checked
                    "a=1.25" :[1.71,1.75], #checked
                    "a=1.5"  :[1.78,1.82], #checked
                    "a=1.75" :[1.84,1.88],
                    "a=2"    :[1.90,2.00], #checked
                    # "a=2"    :[1.916,1.920], #checked
                    # "a=2"    :[1.9176,1.9176], #checked
                    "a=2.25" :[1.95,1.99],
                    "a=2.5"  :[1.98,2.02], #checked
                    "a=2.75" :[2.02,2.06],
                    # "a=3"    :[2.07,2.11], #checked
                    "a=3"    :[2.07,2.08],
                    "a=3.25" :[2.08,2.12],
                    "a=3.5"  :[2.10,2.14], #checked
                    "a=3.75" :[2.13,2.17],
                    "a=4"    :[2.15,2.19],
                    "a=100"  :[2.26918,2.26918], #checked
}

for i in range(len(alpha2)):
    folder_name = "1018_pow0" + str(i)
    input_data_generator('.',folder_name,lattice,equil_dict,mcs_dict,*alpha_crit_range_dict_ideal["a="+str(alpha2[i])],alpha2[i],kBin=20)

# %%
## Code 2: Input configuration file generator

path    = "./"
# lattice = [16,32,48,64,80]
lattice = [6,8,12,16,24,32,48,64,80,128]

# alpha2   = [0.5,0.75,1.25,1.75,2.25,2.75,3.25,3.75,4]
alpha2   = [2]

equil_dict = {
    6 :0,
    8 :0,
    12:0,
    16:0,
    24:0,
    32:0,
    48:0,
    64:0,
    80:0,
    128:0
    }

mcs_dict   = {
    6 :2**25,
    8 :2**25,
    12:2**25,
    16:2**25,
    24:2**25,
    32:2**25,
    48:2**25,
    64:2**25,
    80:2**25,
    128:2**25,
    }


alpha_crit_range_dict_ideal = {
                    "a=0.5"  :[1.34,1.38],
                    "a=0.75" :[1.50,1.54],
                    # "a=1"    :[1.61,1.65], #checked
                    "a=1"    :[1.630,1.630], #checked
                    "a=1.25" :[1.71,1.75], #checked
                    "a=1.5"  :[1.78,1.82], #checked
                    "a=1.75" :[1.84,1.88],
                    # "a=2"    :[1.90,1.94], #checked
                    "a=2"    :[1.920,1.920], #checked
                    "a=2.25" :[1.95,1.99],
                    "a=2.5"  :[1.98,2.02], #checked
                    "a=2.75" :[2.02,2.06],
                    # "a=3"    :[2.07,2.11], #checked
                    "a=3"    :[2.075,2.075],
                    "a=3.25" :[2.08,2.12],
                    "a=3.5"  :[2.10,2.14], #checked
                    "a=3.75" :[2.13,2.17],
                    "a=4"    :[2.15,2.19],
                    "a=100"  :[2.25,2.29], #checked
}

for i in range(len(alpha2)):
    folder_name = "1018_bbin" + str(i)
    input_data_generator('.',folder_name,lattice,equil_dict,mcs_dict,*alpha_crit_range_dict_ideal["a="+str(alpha2[i])],alpha2[i],kBin=10)
