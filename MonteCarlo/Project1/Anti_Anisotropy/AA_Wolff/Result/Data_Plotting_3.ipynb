# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import inspect

currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
# grandparentdir = os.path.dirname(os.path.dirname(os.path.dirname(os.path.dirname(currentdir)))) + '/python_utils'
grandparentdir = '/home/kss/_2022/MonteCarlo'
sys.path.insert(0, grandparentdir + '/python_utils') 

from Exact_Ising_model import *
from Draw_module_1  import *

# %%
alpha_crit_range_dict = {
                    "a=1"    :[1.58,1.64],
                    "a=1.5"  :[1.76,1.82],
                    "a=2"    :[1.88,1.94],
                    "a=2.5"  :[1.96,2.02],
                    "a=3"    :[2.06,2.12],
                    "a=3.5"  :[2.08,2.14],
                    "a=100"  :[2.22,2.28],
}
alpha_crit_dict = {}
alpha_file_name_dict = {
                    "a=1"    :"1.000000",
                    "a=1.5"  :"1.500000",
                    "a=2"    :"2.000000",
                    "a=2.5"  :"2.500000",
                    "a=3"    :"3.000000",
                    "a=3.5"  :"3.500000",
                    "a=100"  :"100.000000",
}
def alpha_to_number(alpha):
    return float(alpha[2:])

# %%
parsing_dict, alpha_list = parsing_helper("./0727/")

# %%
alpha_list
# Out:
# ['a=1', 'a=1.5', 'a=2', 'a=2.5', 'a=3', 'a=3.5', 'a=100']

# %%
parsing_dict['a=1']
# Out:
# [['./0727/a=1/AA_SwendsenWang_c_16_16_int31_mcs100000_a1.000000_Jackknife__1.csv',
#   './0727/a=1/AA_SwendsenWang_c_32_32_int31_mcs100000_a1.000000_Jackknife__1.csv',
#   './0727/a=1/AA_SwendsenWang_c_48_48_int31_mcs150000_a1.000000_Jackknife__1.csv',
#   './0727/a=1/AA_SwendsenWang_c_64_64_int31_mcs150000_a1.000000_Jackknife__1.csv',
#   './0727/a=1/AA_SwendsenWang_c_96_96_int31_mcs200000_a1.000000_Jackknife__1.csv'],
#  [16, 32, 48, 64, 96],
#  [31, 31, 31, 31, 31],
#  [100000, 100000, 150000, 150000, 200000]]

# %%
alpha = alpha_list[0]
draw_multi(*parsing_dict[alpha])
draw_binder_FFS(*parsing_dict[alpha],alpha_crit_range_dict[alpha], Tc = 1.63)
alpha_crit_dict[alpha] = 1.63

# %%
alpha = alpha_list[1]
draw_multi(*parsing_dict[alpha])
draw_binder_FFS(*parsing_dict[alpha],alpha_crit_range_dict[alpha], Tc = 1.795)
alpha_crit_dict[alpha] = 1.795

# %%
alpha = alpha_list[2]
draw_multi(*parsing_dict[alpha])
draw_binder_FFS(*parsing_dict[alpha],alpha_crit_range_dict[alpha], Tc = 1.92)
alpha_crit_dict[alpha] = 1.92

# %%
alpha = alpha_list[3]
draw_multi(*parsing_dict[alpha])
draw_binder_FFS(*parsing_dict[alpha],alpha_crit_range_dict[alpha], Tc = 2.005)
alpha_crit_dict[alpha] = 2.005

# %%
alpha = alpha_list[4]
draw_multi(*parsing_dict[alpha])
draw_binder_FFS(*parsing_dict[alpha],alpha_crit_range_dict[alpha], Tc = 2.075)
alpha_crit_dict[alpha] = 2.075

# %%
alpha = alpha_list[5]
draw_multi(*parsing_dict[alpha])
draw_binder_FFS(*parsing_dict[alpha],alpha_crit_range_dict[alpha], Tc = 2.125)
alpha_crit_dict[alpha] = 2.125

# %%
parsing_dict[alpha]
# Out:
# [['./0727/a=3.5/AA_SwendsenWang_c_16_16_int31_mcs100000_a3.500000_Jackknife__1.csv',
#   './0727/a=3.5/AA_SwendsenWang_c_32_32_int31_mcs100000_a3.500000_Jackknife__1.csv',
#   './0727/a=3.5/AA_SwendsenWang_c_48_48_int31_mcs150000_a3.500000_Jackknife__1.csv',
#   './0727/a=3.5/AA_SwendsenWang_c_64_64_int31_mcs150000_a3.500000_Jackknife__1.csv',
#   './0727/a=3.5/AA_SwendsenWang_c_96_96_int31_mcs200000_a3.500000_Jackknife__1.csv'],
#  [16, 32, 48, 64, 96],
#  [31, 31, 31, 31, 31],
#  [100000, 100000, 150000, 150000, 200000]]

# %%
alpha = alpha_list[6]
draw_multi(*parsing_dict[alpha])
draw_binder_FFS(*parsing_dict[alpha],alpha_crit_range_dict[alpha], Tc = 2.27)
alpha_crit_dict[alpha] = 2.27

# %%
# critical_T = [1.62,1.79,1.91,2.0,2.08,2.12,2.27]
critical_T = []
alpha_num  = []
for alpha in alpha_list:
    alpha_num.append(alpha_to_number(alpha))
    critical_T.append(alpha_crit_dict[alpha])

plt.plot(alpha_num,critical_T,"-s")
plt.xlabel("alpha")
plt.ylabel("Critical Temp")
plt.xlim(1,4)
# Out:
# (1.0, 4.0)

# %%
alpha_crit_dict
# Out:
# {'a=1': 1.63,
#  'a=1.5': 1.795,
#  'a=2': 1.92,
#  'a=2.5': 2.005,
#  'a=3': 2.075,
#  'a=3.5': 2.125,
#  'a=100': 2.27}
